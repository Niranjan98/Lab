# %% [markdown]
# <a href="https://colab.research.google.com/github/Niranjan98/Lab/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
n=1000
X=np.linspace(-3,3,num=n)
y=np.log(np.abs((X**2)-1)+0.5)
X+=np.random.normal(scale=.05,size=n)
plt.scatter(X,y,alpha=.3)

# %%
def local_regression(x0, X, Y, tau):
  x0 = np.r_[1, x0]
  X = np.c_[np.ones(len(X)), X]
  xw = X.T * radial_kernel(x0, X, tau)
  beta = np.linalg.pinv(xw @ X) @ xw @ Y
  return x0 @ beta

# %%
def radial_kernel(x0, X, tau):
  return np.exp(np.sum((X - x0) ** 2, axis=1) / (-2 * tau ** 2))

# %%
def plot_lwr(tau):
  domain = np.linspace(-3, 3, num=300)
  prediction = [local_regression(x0, X, y, tau) for x0 in domain]
  plt.scatter(X, y, alpha=.3)
  plt.plot(domain, prediction, color='red')
  return plt

# %%
plot_lwr(0.04)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>
